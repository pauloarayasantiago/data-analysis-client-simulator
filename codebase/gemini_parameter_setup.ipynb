# %%
# Cell 1: Imports
import google.generativeai as genai
import os
from datetime import datetime
import re
import time  # Import the time module

# Cell 2: API Key and Model Setup
# Load the API key from environment variables and configure the model properly
GOOGLE_API_KEY = os.getenv('GOOGLE_API_KEY')  # Make sure you have set this environment variable
if not GOOGLE_API_KEY:
    raise ValueError("Please set the GOOGLE_API_KEY environment variable")

genai.configure(api_key=GOOGLE_API_KEY)

# Initialize the model with safety settings
# Base generation configuration with max_output_tokens fixed, and no top_p or top_k
base_generation_config = {
    "max_output_tokens": 2048,
}

model = genai.GenerativeModel(
    model_name="gemini-1.5-pro-latest",
    generation_config=base_generation_config,
)

# Cell 3: Prompt Definition
client_sim_prompt = """
    You are a creative writing expert tasked with generating diverse and unique client profiles.
    Generate **ONE** client profile and the details of **ONE** realistic business problem that this client needs solved.
    Make sure that this client is completely unique and different from any other client that you have previously generated, they must have a different name, a different background, and come from a different period of time.
    As the client, describe your personality, background, and any specific quirks or communication styles you might have.
    Explain the business problem from the perspective of the client, what the context is and what the specific problem or question to be solved is. Include fictional demands, caveats, and surprises that are relevant to me as the client.
    Speak in first person, and make sure you include your full name, as the very first string in the response in the following format, **as an example**:
    John Smith:
    """

# Cell 4: Parameter Tuning and Generation
# Define the ranges for the temperature you want to tune
temperatures = [i * 0.2 for i in range(1, 11)] # Generates temperatures from 0.2 to 2.0 with a 0.2 step

# Iterate through the temperatures
for temperature in temperatures:
    # Update the generation configuration for this temperature
    tuned_generation_config = {
        "temperature": temperature,
        "max_output_tokens": base_generation_config["max_output_tokens"], # Keep max_output_tokens constant
    }

    # Update the model's generation config
    model.generation_config = tuned_generation_config

    # Generate content with the current configuration
    try:
        response = model.generate_content(client_sim_prompt)
        if response:
            response.resolve() # Ensure the response is resolved
            print(f"--- Configuration: Temperature={temperature} (Top-P and Top-K at default) ---")
            print(response.text)
            print("\n" + "="*50 + "\n") # Separator for clarity
        else:
            print(f"--- Configuration: Temperature={temperature} (Top-P and Top-K at default) ---")
            print("Error: Received an empty response from the model.")
            print("\n" + "="*50 + "\n") # Separator for clarity
    except AttributeError as e:
        print(f"--- Configuration: Temperature={temperature} (Top-P and Top-K at default) ---")
        print(f"AttributeError encountered (likely a NoneType error): {e}")
        print("This usually means the response object was None.")
        print("\n" + "="*50 + "\n") # Separator for clarity
    except Exception as e:
        print(f"--- Configuration: Temperature={temperature} (Top-P and Top-K at default) ---")
        print(f"An unexpected error occurred during text generation: {e}")
        print("\n" + "="*50 + "\n") # Separator for clarity

    time.sleep(5)  # Introduce a 5-second delay between requests
# Out:
# --- Configuration: Temperature=0.2 (Top-P and Top-K at default) ---
# Esmeralda "Esme" Reyes-O'Malley:
#
# Right, so, let's get one thing straight. I don't do "fluff."  No flowery language, no beating around the bush.  I'm a woman of science, dammit, a botanist to be precise, and I expect clear, concise communication. I'm Dr. Reyes-O'Malley, though everyone calls me Esme, and I'm speaking to you from 1928, through… well, however this time-travel gramophone thingamajig works.  My specialty is the study of carnivorous plants, particularly the Nepenthes genus, those fascinating pitcher plants. I spent years traipsing through the jungles of Borneo, meticulously documenting their digestive enzymes.  Yes, I’ve been called eccentric. I prefer “dedicated.” I talk to my plants, which I’ve named after famous opera singers.  Don’t judge me. They seem to appreciate it. I also have a rather… intense aversion to the color beige. It reminds me of poorly preserved specimens.  And don't even get me started on the patriarchy trying to stifle my research because I wear trousers.
#
# My problem, and it’s a rather thorny one, involves a new species of Nepenthes I discovered on my last expedition.  I call it *Nepenthes mirabilis gigantea* – the miraculous giant. This thing is enormous, easily ten times the size of any known pitcher plant. Its pitchers are large enough to… well, let’s just say a small dog wouldn’t want to fall in.  It produces an unusually potent digestive enzyme, one that seems capable of breaking down organic matter at an astonishing rate. I documented the initial observations, but my funding was abruptly cut off by the Royal Geographic Society (those stuffy old fools claimed my research was “too unorthodox”). They confiscated all my samples! The nerve!
#
# What I need is someone to recreate this enzyme – synthetically.  I have detailed sketches and notes (hidden in a secret compartment in my boot, don't you worry), but I lack the advanced laboratory equipment necessary for synthesis.  I believe this enzyme has incredible potential applications, from waste disposal to, dare I say it, medicine.  The caveat?  It needs to be done discreetly. The Royal Geographic Society is watching my every move. And absolutely NO beige equipment.  I'll know. And, if you succeed, I’ll name a newly discovered cultivar of *Drosera* after you. That's a sundew, for the uninitiated.  Consider it the highest honor a botanist can bestow.  Now, get to work! Time is of the essence, and my Brunhilde (that's my prize-winning *Nepenthes rajah*) is looking rather peckish.
#
#
# ==================================================
#
# --- Configuration: Temperature=0.4 (Top-P and Top-K at default) ---
# Hepzibah Pruitt:
#
# I'm Hepzibah Pruitt, and I swear on my great-aunt Millie's prized pickle recipe, I've never met anyone quite like myself. Born and bred in the Appalachian Mountains in 1888, I'm what you might call a "mountain woman" – though I prefer "independent businesswoman." I built my entire fortune selling homemade remedies, particularly my "Pruitt's Pinnacle Elixir," which can cure everything from a common cold to a lovesick heart (at least, that's what folks say). I'm blunt, I'm practical, and I don't suffer fools gladly.  I believe in plain speaking and honest dealings.  Don't try to flatter me or use fancy city-slicker words, just get straight to the point.  I'm also a tad superstitious.  Bad omens make me nervous, so avoid mentioning black cats or broken mirrors around me.
#
# Now, about my problem. My Elixir is the talk of the hollers, and demand is higher than a hawk circling a field mouse.  Folks come from miles around to get their hands on a bottle.  But my methods are, shall we say, "traditional."  I mix every batch by hand under the light of the full moon, using ingredients I forage from the mountains. This means production is slow, and I can’t keep up.  I’ve heard tell of these newfangled "factories" up north that can churn out goods faster than a fiddle player at a barn dance.
#
# I need someone to help me figure out how to scale up my elixir production without sacrificing quality or, heaven forbid, losing the magic touch.  I’m willing to consider new methods, but I have a few demands:  first, no unnatural ingredients.  Everything must be sourced from nature, just like I’ve always done.  Second, I will not have any of those noisy, smoke-belching contraptions anywhere near my mountain.  This elixir needs the quiet tranquility of these hills to brew properly. And finally, there's the little matter of my great-great-grandmother’s ghost, Agnes.  She appears whenever big changes are afoot, and she’s a bit…opinionated.  Be prepared for her spectral input.  She fancies herself a bit of a business consultant, though her advice usually comes in the form of cryptic whispers and flickering lamps.  Don't worry too much if she throws a spectral tantrum. She usually settles down after a cup of chamomile tea (which, thankfully, she can no longer drink).  So, are you up for the challenge?
#
#
# ==================================================
#
# --- Configuration: Temperature=0.6000000000000001 (Top-P and Top-K at default) ---
# Esmeralda Velasquez:
#
# I'm Esmeralda Velasquez, and darling, let me tell you, life has been a whirlwind. Born in 1923 in Havana, Cuba, I've seen it all – from the glitz and glamour of pre-revolution Cuba to the grit and resilience of exile in Miami. I built my empire, "Azúcar," from the ground up. It started as a small bakery, selling my abuela's secret recipes for pastelitos and guava pastries. Now, it's a chain of thriving Cuban restaurants across South Florida, each one a little slice of the Havana I remember.
#
# I'm passionate, fiery, and I don't mince words.  I believe in hard work, loyalty, and the power of a perfectly brewed cafecito.  I'm also fiercely protective of my legacy.  "Azúcar" is more than just a business; it's a testament to my family, my heritage, and my unwavering spirit. My communication style is direct, sometimes blunt, but always laced with a touch of that Cuban charm. I expect the same level of candor and respect in return. Don't waste my time with flowery language or corporate jargon; just tell me what I need to know.
#
# Now, about the problem. My "Azúcar" restaurants are doing well, but I'm facing a new challenge: the millennials. These kids, with their avocado toast and their… *internet*, they just don't seem to connect with the "Azúcar" brand the way their parents and grandparents do. They want flashy, "Instagrammable" food, and they're obsessed with "authenticity" (which, ironically, they seem to find everywhere except in my authentic Cuban restaurants).  My regular customers, my loyal base, they are still coming, thank goodness. But I need to bring in this younger generation if "Azúcar" is to survive and thrive in the 21st century.
#
# I need a marketing strategy that bridges this generational gap.  I want something that respects the "Azúcar" legacy – no gimmicks, no betraying our roots – but also speaks to these modern palates and sensibilities. I refuse to compromise on the quality of my food. My abuela’s recipes are sacred.  And absolutely no fusion cuisine! I don't want to see some monstrosity like a "Cuban-Korean BBQ" taco on my menu.
#
# Here's the kicker: I want this entire marketing campaign centered around a fictional character, a charismatic, fictional “face” of "Azúcar," a figure who embodies the spirit of Cuba and connects with both young and old.  I'm open to suggestions, but I envision a glamorous, witty woman, perhaps a fictionalized version of myself in my younger days.  Think Rita Moreno meets Lucille Ball with a dash of Celia Cruz.  Get it done, and you'll be rewarded handsomely. Fail, and well… let's just say you don't want to be on my bad side.  I also have a soft spot for stray dogs, so a portion of your fee must be donated to the local animal shelter. That's non-negotiable.  Surprise me.  Astonish me.  Make me believe in millennials again.
#
#
# ==================================================
#
# --- Configuration: Temperature=0.8 (Top-P and Top-K at default) ---
# Esmeralda "Esme" Rodriguez-O'Malley:
#
# I'm Esme, a whirlwind of frenetic energy and brightly-colored scarves. Born in 1928, I clawed my way from a cramped tenement in Spanish Harlem to become the owner of Esme's Emporium, the most vibrant and eclectic vintage clothing store in Greenwich Village. I’ve always had a nose for fashion, a keen eye for quality, and a silver tongue that could charm the birds out of the trees. My store is a testament to my journey, a kaleidoscope of bygone eras, bursting with flapper dresses, poodle skirts, Nehru jackets, and everything in between.  I’m a tough cookie with a soft center, fluent in both Spanglish and the language of sequins. I'm also a bit of a hoarder – sentimentality gets the better of me – so my store is… packed.  Think organized chaos. I’m old school.  Don’t email me.  Call me, preferably between the hours of 2 and 4 PM, and be prepared for a rapid-fire conversation.  And don't try to sell me snake oil.  I can smell a phony a mile away.
#
# My problem?  The internet.  This "world wide web" everyone’s raving about.  Frankly, it terrifies me.  My granddaughter, bless her heart, keeps telling me I need to get online, create a website, sell my treasures to the masses.  She says it’ll “revolutionize” my business.  Revolution, schrevolution! I built this empire on handshakes and haggling, not clicks and algorithms.  But the foot traffic isn't what it used to be. My loyal customers are… well, they’re not getting any younger. I’m afraid Esme’s Emporium might become a relic itself if I don’t adapt.
#
# So, here’s what I need: someone who can translate this "internet" thing into my language.  Someone who can build me a website that captures the magic of my store, the stories whispered by each garment, the history woven into every thread.  I don’t want some sterile, corporate-looking site.  I want it to feel like stepping into my store, the scent of mothballs and vintage perfume included (figuratively, of course!).  Caveat: Absolutely no plastic mannequins! They’re soulless.  And no models – they never do the clothes justice. I have a collection of antique dress forms with more personality.  Surprise:  If you can convince me this internet thing is worth my time, and build me a website that truly captures the spirit of Esme's Emporium, I’ll let you choose any one item from my personal collection – a genuine 1920s flapper dress, a pair of perfectly preserved 1950s cat-eye sunglasses, a signed photo of Carmen Miranda… you name it. But it has to be truly spectacular.  Capiche?
#
#
# ==================================================
#
# --- Configuration: Temperature=1.0 (Top-P and Top-K at default) ---
# Error generating text: 'NoneType' object has no attribute 'from_call'
#
# ==================================================
#
# --- Configuration: Temperature=1.2000000000000002 (Top-P and Top-K at default) ---
# Error generating text: 'NoneType' object has no attribute 'from_call'
#
# ==================================================
#
# --- Configuration: Temperature=1.4000000000000001 (Top-P and Top-K at default) ---
# Esmeralda Weatherby:
#
# I'm Esmeralda Weatherby, and darling, don't you forget it.  I built my empire, Weatherby's Wonderful Wigs, from the ground up in the roaring twenties.  Started with a single shop in Chicago, catering to flappers and their bobbed hair regrets.  Now, I've got franchises popping up faster than speakeasies during Prohibition.  I'm all about glamour, glitz, and getting what I want. I'm a straight shooter, tell it like it is, no sugar-coating.  Don't waste my time with fluff, give it to me straight, and fast.  I'm used to people telling me "yes," so "no" isn't really in my vocabulary.  I speak my mind, and I expect you to do the same, but don't forget who's holding the purse strings.  And for heaven's sake, don't call me "ma'am," unless you want to find yourself on the wrong side of a marcel wave.
#
#
# My problem, darling, is synthetic fibers. These newfangled nylon stockings are all the rage, and everyone’s buzzing about how they might revolutionize other industries.  Now,  I've built my business on high-quality human hair.  It's what Weatherby's is known for - luxurious, natural, gorgeous.  But these synthetics… they’re cheap.  Dirt cheap. And that worries me. If someone figures out how to make a decent-looking wig out of this stuff, I could be in trouble. So, here’s what I need: I want you to find out everything there is to know about these synthetic fibers.  Can they be styled like human hair? How do they hold up over time?  Most importantly, can they be made into a wig that even *I* would wear?  I want samples, reports, the whole shebang.  I need to know if I should be incorporating this stuff into my own line or figuring out how to crush it before it crushes me.
#
# Now for the caveats:  absolute discretion.  This is need-to-know only. My competitors can’t get wind of this. And I expect results yesterday.  I’ve also heard rumors of a new hair tonic being developed in Paris that supposedly makes hair grow inches overnight. I want you to look into that too. Discreetly, of course.  And lastly, surprise me.  Throw something unexpected into your final presentation.  A new wig design, a marketing idea, anything that shows me you're not just another yes-man. I reward creativity generously, darling.  But bore me, and you’ll find yourself selling newspapers on a street corner.  You got that?
#
#
# ==================================================
#
# --- Configuration: Temperature=1.6 (Top-P and Top-K at default) ---
# Aloysius Pendergast:
#
# I am Aloysius Pendergast, and I assure you, my requirements are… particular.  I am a Special Agent with the Federal Bureau of Investigation, though my methods often stray from the accepted Bureau protocols.  My background is… complex. Let us simply say it involves extensive travel, an upbringing steeped in arcane knowledge, and a certain… appreciation for the finer things in life.  I prefer tailored suits of the finest Italian silk, rare first editions, and a good vintage Armagnac. My communication style is direct, though often veiled in a layer of quiet observation and meticulous detail. I dislike imprecision and emotional outbursts.  Do not waste my time with frivolous chatter or attempts at forced camaraderie.
#
# My current predicament, and thus my reason for requiring your… unique services, revolves around a series of seemingly unconnected events.  Three individuals, each prominent figures in their respective fields – a renowned astrophysicist, a celebrated opera singer, and a reclusive art collector – have all perished in remarkably bizarre circumstances.  The local authorities have deemed these deaths accidental, tragic, but ultimately explainable. I, however, am not convinced.  There is an unsettling symmetry to these incidents, a subtle, almost imperceptible pattern that suggests a more… sinister hand at play.  The nature of these deaths defies conventional explanation, hinting at something beyond the realm of the mundane.  The astrophysicist, for example, was found in his observatory, seemingly incinerated from the inside out, despite no evidence of fire. The opera singer expired mid-performance, her voice abruptly silenced as if… stolen. The art collector? Discovered within his locked vault, surrounded by his prized possessions, yet utterly devoid of… life force.  It’s as though something has extracted the very essence of their being.
#
# My demand is simple: I require a narrative. A cohesive explanation that connects these seemingly disparate events.  I do not seek mere speculation, but a meticulously crafted theory, grounded in logic, yet open to the… unconventional.  Your research must be discreet.  The Bureau is… unaware of my involvement in this matter.  Furthermore, I expect absolute confidentiality.  Should a single word of this investigation reach the wrong ears, the consequences will be… unpleasant.  Be warned, however, this investigation delves into the esoteric, the inexplicable.  You may encounter… things that challenge your perception of reality.  If you are faint of heart, or prone to conventional thinking, I suggest you decline my offer.  Now, are you up to the task, or shall I seek assistance elsewhere?  There is one final caveat:  should you uncover the truth, I will require proof, tangible evidence that can stand up to scrutiny, even if that proof lies outside the realm of… accepted science. And, a small surprise for you – should your narrative prove satisfactory, I will reward you with a first edition copy of John Dee's *Monas Hieroglyphica*.  It is… quite rare.
#
#
# ==================================================
#
# --- Configuration: Temperature=1.8 (Top-P and Top-K at default) ---
# Esmeralda Weatherwax:
#
# I'm Esmeralda Weatherwax, but everyone calls me Esme.  I run Weatherwax's Wonderful Weatherworks, the only dedicated weather manipulation service in the bustling port city of New Bristol, 1888.  I inherited it from my great-aunt Esmeralda (a powerful woman, she was – could conjure a hurricane in a teacup), and I’ve been running it for the past ten years. My specialty is bespoke weather – weddings, sporting events, you name it, I can make the skies sing your tune. I’m known for my precision and reliability; my motto is “Rain or shine, your weather is mine!”
#
# I’m a no-nonsense woman.  Direct, to the point, and I don't suffer fools gladly. I have a bit of a reputation for being…eccentric, but mostly because I talk to my cat, Fitzwilliam, who I firmly believe offers excellent business advice. (He’s a ginger Persian, extremely fluffy and judgmental. Don’t tell him I said that).  I also have a penchant for strong tea and even stronger opinions, and I expect people to be punctual.  If you're late, I charge extra.  Time, like the weather, is a precious commodity.
#
# My problem, you see, is these newfangled "automata." Clockwork contraptions they are, sprouting up all over the city, doing all sorts of jobs that used to require honest, hardworking folk.  And now, one of those blasted gizmos, called the "Atmospheric Regulator," is claiming it can control the weather!  It’s preposterous!  Utter hogwash! It's bad enough these metal monstrosities are taking jobs, but now they're trying to take over my livelihood!  The nerve!
#
# I need you to discredit this Atmospheric Regulator.  Prove it's a fraud. I want irrefutable evidence that it’s nothing more than a glorified tea kettle, spouting steam and empty promises.  I need pamphlets, newspaper articles, scientific testimonials – the works!  And I want it done discreetly.  If those automaton makers get wind of my plan, they might try to… "influence" things.
#
# Caveat: I refuse to use any form of "modern technology"  (that includes those new-fangled typewriters!).  All communication must be handwritten on quality parchment.  And Fitzwilliam must approve of the final product.  He has a keen eye for discerning truth from fabrication, you see.
#
# Surprise: If you successfully complete this task and manage to win over Fitzwilliam (good luck with that, he’s a tough nut to crack), I will reward you with a year’s worth of bespoke weather, tailored specifically to your needs.  Think sunny picnics every Sunday, a gentle breeze during your morning commute, and absolutely no snow on your birthday.  It's a deal no sane person could refuse.
#
#
# ==================================================
#
# --- Configuration: Temperature=2.0 (Top-P and Top-K at default) ---
# Aloysius Pankhurst:
#
# I’m Aloysius Pankhurst, but everyone calls me Al.  I’m a clockmaker, born and bred in Edinburgh, 1888. I run my wee shop just off the Royal Mile, inherited from my father, and his father before him.  I'm not a man of grand pronouncements or flowery language, mind you. Plain speaking is my way, just like the steady tick-tock of a well-made timepiece. I’m meticulous to a fault; some might even say obsessive. Every gear, every spring, every hand must be perfectly aligned, or it simply won’t do.  I appreciate a straightforward approach, no beating around the bush.  I can be a bit… prickly, if folks waste my time with frivolous chatter.  But I’m fair, and I pay well for good work, especially if it's done with precision and a respect for tradition.
#
# My problem, well, it’s a bit of a… conundrum.  See, I’ve received a commission, the most prestigious of my career. A wealthy American industrialist, name of Rockefeller – yes, *that* Rockefeller – wants a clock.  Not just any clock, mind. He wants a clock that tells the future.  I know, sounds daft, right?  But he’s dead serious. He's sent me a hefty advance, enough to set me up for life, with the promise of double that upon completion. He’s given me some vague notions about incorporating  "newfangled electrical doohickeys" and "scientific principles" I barely understand. He's even sent a crate of these bizarre glowing tubes he calls "vacuum something-or-others." I haven't the foggiest idea what to do with them! I'm a clockmaker, not a magician!
#
# The demand is clear: a clock that can predict the stock market. Rockefeller believes that by harnessing the "invisible forces" of electricity and magnetism, we can glimpse the future of his investments. Absurd, I know! But the money's good, and the challenge… well, it's intriguing, to say the least.
#
# The caveat? Absolute secrecy. This must stay between us.  If word gets out, especially to my competitors, I'm ruined. And Rockefeller, well, he's not a man you want to cross.
#
# The surprise? He expects a working prototype within six months. Six months! For a clock that tells the future!  The man's clearly mad, but the money’s real enough.  So, if you’re some kind of… visionary, a genius with these newfangled contraptions, and you can keep a secret tighter than a drum, I might just have a proposition for you.  But be warned, I have no patience for fools. So come prepared, and don't waste my time.
#
#
# ==================================================
